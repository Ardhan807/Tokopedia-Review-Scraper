# %%
import pandas as pd
df = pd.read_csv('fantech_review.csv')
df
# Out:
#                                                review  rating  \
# 0        meskipun pengiriman lama tapi overall bagus.       5
# 1                                      Kualitas bagus       5
# 2                                               Bagus       5
# 3   Performa sistem: bagusss\nKualitas pengerjaan:...       5
# 4                                                enak       5
# 5                                           Mantap!!!       5
# 6                                           so so lah       4
# 7   Saran buat Fantech, suaranya kalo setengah max...       4
# 8   Mantap pengirimannya, cuma 3 hari sdh sampai d...       5
# 9   Quality of work: bekerja dengan baik\nSystem p...       5
# 10  Quality of work: Kualitas sesuai baguss\nPerfo...       5
# 11  sangat bagus banget, pertama baranv dikirim ad...       5
# 12  Kualitas dari Fantech? Coba liat sendiri dari ...       5
# 13                                         Bahan: sip       5
# ...
